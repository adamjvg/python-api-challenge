# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress


# Import API key
from api_keys import api_key
temp_units = "metric"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output/weather_df.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={temp_units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

# %% [markdown]
# ## Generate Cities List

# %%
# create list for latitudes and longitudes
lat_lngs = []
cities = []

# use random to generate a bunch of latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# get the nearest city from these values
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# only unique cities are used
    if city not in cities:
        cities.append(city)

# check if we have enough cities
len(cities)
# Out:
# 585

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Checking weather {count_one} of Set {set_one} | {city}")
    except Exception:
        print(f"{city} not found. Next...")
print("------------------------------")
print("All Done!")
print("------------------------------")
# Out:
# Checking weather 1 of Set 1 | tiksi
# Checking weather 2 of Set 1 | vaini
# amderma not found. Next...
# illoqqortoormiut not found. Next...
# Checking weather 3 of Set 1 | marzuq
# Checking weather 4 of Set 1 | lorengau
# Checking weather 5 of Set 1 | bredasdorp
# Checking weather 6 of Set 1 | barrow
# Checking weather 7 of Set 1 | yafran
# Checking weather 8 of Set 1 | east london
# Checking weather 9 of Set 1 | ostrovnoy
# Checking weather 10 of Set 1 | busselton
# Checking weather 11 of Set 1 | yellowknife
# Checking weather 12 of Set 1 | rikitea
# Checking weather 13 of Set 1 | parana
# Checking weather 14 of Set 1 | ushuaia
# Checking weather 15 of Set 1 | castro
# barentsburg not found. Next...
# Checking weather 16 of Set 1 | new norfolk
# Checking weather 17 of Set 1 | hilo
# la ronge not found. Next...
# Checking weather 18 of Set 1 | bilibino
# Checking weather 19 of Set 1 | hermanus
# Checking weather 20 of Set 1 | samarai
# Checking weather 21 of Set 1 | cape town
# Checking weather 22 of Set 1 | bluff
# Checking weather 23 of Set 1 | kieta
# Checking weather 24 of Set 1 | saint-philippe
# Checking weather 25 of Set 1 | norman wells
# Checking weather 26 of Set 1 | fortuna
# Checking weather 27 of Set 1 | tselinnoye
# Checking weather 28 of Set 1 | akhtubinsk
# Checking weather 29 of Set 1 | terme
# Checking weather 30 of Set 1 | kruisfontein
# Checking weather 31 of Set 1 | angoche
# Checking weather 32 of Set 1 | zeya
# Checking weather 33 of Set 1 | port alfred
# Checking weather 34 of Set 1 | tupancireta
# Checking weather 35 of Set 1 | grand gaube
# Checking weather 36 of Set 1 | yar-sale
# Checking weather 37 of Set 1 | punta arenas
# Checking weather 38 of Set 1 | mys shmidta
# Checking weather 39 of Set 1 | mataura
# Checking weather 40 of Set 1 | nome
# Checking weather 41 of Set 1 | jumla
# Checking weather 42 of Set 1 | victoria
# Checking weather 43 of Set 1 | mahebourg
# taolanaro not found. Next...
# Checking weather 44 of Set 1 | albany
# Checking weather 45 of Set 1 | regina
# Checking weather 46 of Set 1 | butaritari
# Checking weather 47 of Set 1 | mimongo
# Checking weather 48 of Set 1 | bengkulu
# Checking weather 49 of Set 1 | labuan
# Checking weather 1 of Set 2 | hobart
# Checking weather 2 of Set 2 | mana
# Checking weather 3 of Set 2 | altay
# Checking weather 4 of Set 2 | alofi
# Checking weather 5 of Set 2 | hobyo
# Checking weather 6 of Set 2 | leningradskiy
# Checking weather 7 of Set 2 | daska
# Checking weather 8 of Set 2 | tasiilaq
# Checking weather 9 of Set 2 | palimbang
# Checking weather 10 of Set 2 | ankazoabo
# Checking weather 11 of Set 2 | warwick
# Checking weather 12 of Set 2 | airai
# Checking weather 13 of Set 2 | provideniya
# Checking weather 14 of Set 2 | ancud
# Checking weather 15 of Set 2 | phan rang
# Checking weather 16 of Set 2 | nikolskoye
# Checking weather 17 of Set 2 | atuona
# Checking weather 18 of Set 2 | taksimo
# Checking weather 19 of Set 2 | kaitangata
# Checking weather 20 of Set 2 | san patricio
# Checking weather 21 of Set 2 | codrington
# Checking weather 22 of Set 2 | ponta do sol
# Checking weather 23 of Set 2 | bethel
# Checking weather 24 of Set 2 | kapaa
# Checking weather 25 of Set 2 | bilma
# Checking weather 26 of Set 2 | pahrump
# Checking weather 27 of Set 2 | oktyabrskoye
# Checking weather 28 of Set 2 | carnarvon
# Checking weather 29 of Set 2 | khatanga
# Checking weather 30 of Set 2 | thinadhoo
# Checking weather 31 of Set 2 | maldonado
# Checking weather 32 of Set 2 | port-gentil
# Checking weather 33 of Set 2 | puerto ayora
# Checking weather 34 of Set 2 | nkan
# Checking weather 35 of Set 2 | udankudi
# Checking weather 36 of Set 2 | goldsboro
# Checking weather 37 of Set 2 | tuktoyaktuk
# Checking weather 38 of Set 2 | klaksvik
# Checking weather 39 of Set 2 | chuy
# Checking weather 40 of Set 2 | port elizabeth
# Checking weather 41 of Set 2 | enid
# Checking weather 42 of Set 2 | greenwood
# Checking weather 43 of Set 2 | mayumba
# Checking weather 44 of Set 2 | qaanaaq
# Checking weather 45 of Set 2 | puerto baquerizo moreno
# Checking weather 46 of Set 2 | palmer
# Checking weather 47 of Set 2 | pevek
# Checking weather 48 of Set 2 | juneau
# Checking weather 49 of Set 2 | dikson
# Checking weather 1 of Set 3 | amapa
# Checking weather 2 of Set 3 | hay river
# Checking weather 3 of Set 3 | carahue
# Checking weather 4 of Set 3 | colac
# Checking weather 5 of Set 3 | arraial do cabo
# saint george not found. Next...
# Checking weather 6 of Set 3 | komsomolskiy
# Checking weather 7 of Set 3 | ulety
# Checking weather 8 of Set 3 | harrai
# Checking weather 9 of Set 3 | cockburn town
# belushya guba not found. Next...
# Checking weather 10 of Set 3 | mar del plata
# umm lajj not found. Next...
# Checking weather 11 of Set 3 | montrose
# Checking weather 12 of Set 3 | lucapa
# Checking weather 13 of Set 3 | coihaique
# Checking weather 14 of Set 3 | balkanabat
# Checking weather 15 of Set 3 | kodiak
# Checking weather 16 of Set 3 | alta floresta
# Checking weather 17 of Set 3 | malinao
# Checking weather 18 of Set 3 | faanui
# Checking weather 19 of Set 3 | narsaq
# Checking weather 20 of Set 3 | bathurst
# Checking weather 21 of Set 3 | ponta delgada
# Checking weather 22 of Set 3 | san francisco
# Checking weather 23 of Set 3 | auki
# Checking weather 24 of Set 3 | san julian
# Checking weather 25 of Set 3 | upernavik
# Checking weather 26 of Set 3 | kampot
# Checking weather 27 of Set 3 | karpathos
# Checking weather 28 of Set 3 | nuuk
# Checking weather 29 of Set 3 | san cristobal
# Checking weather 30 of Set 3 | wattegama
# Checking weather 31 of Set 3 | kibuye
# Checking weather 32 of Set 3 | casa nova
# Checking weather 33 of Set 3 | imbituba
# Checking weather 34 of Set 3 | severo-kurilsk
# Checking weather 35 of Set 3 | canchungo
# Checking weather 36 of Set 3 | juba
# Checking weather 37 of Set 3 | santa rosa
# Checking weather 38 of Set 3 | touros
# Checking weather 39 of Set 3 | muzaffarpur
# Checking weather 40 of Set 3 | hithadhoo
# Checking weather 41 of Set 3 | praia da vitoria
# Checking weather 42 of Set 3 | zhangye
# Checking weather 43 of Set 3 | waingapu
# Checking weather 44 of Set 3 | torbay
# Checking weather 45 of Set 3 | laguna
# Checking weather 46 of Set 3 | qaqortoq
# Checking weather 47 of Set 3 | lagoa
# Checking weather 48 of Set 3 | pacifica
# Checking weather 49 of Set 3 | port hawkesbury
# Checking weather 1 of Set 4 | gweta
# kuche not found. Next...
# Checking weather 2 of Set 4 | grindavik
# nizhneyansk not found. Next...
# Checking weather 3 of Set 4 | avarua
# Checking weather 4 of Set 4 | broome
# mrirt not found. Next...
# Checking weather 5 of Set 4 | thompson
# Checking weather 6 of Set 4 | erzin
# Checking weather 7 of Set 4 | tilichiki
# Checking weather 8 of Set 4 | banda aceh
# meyungs not found. Next...
# Checking weather 9 of Set 4 | rawson
# gurskoye not found. Next...
# Checking weather 10 of Set 4 | lebu
# Checking weather 11 of Set 4 | padang
# Checking weather 12 of Set 4 | dongsheng
# Checking weather 13 of Set 4 | ginir
# Checking weather 14 of Set 4 | ilulissat
# Checking weather 15 of Set 4 | ribeira grande
# Checking weather 16 of Set 4 | jamestown
# Checking weather 17 of Set 4 | shu
# Checking weather 18 of Set 4 | lichinga
# Checking weather 19 of Set 4 | mackay
# Checking weather 20 of Set 4 | price
# Checking weather 21 of Set 4 | smithers
# Checking weather 22 of Set 4 | grand river south east
# samusu not found. Next...
# Checking weather 23 of Set 4 | cidreira
# Checking weather 24 of Set 4 | iqaluit
# Checking weather 25 of Set 4 | norden
# Checking weather 26 of Set 4 | inhambane
# tabiauea not found. Next...
# Checking weather 27 of Set 4 | monrovia
# Checking weather 28 of Set 4 | neftegorsk
# Checking weather 29 of Set 4 | lompoc
# Checking weather 30 of Set 4 | fort nelson
# Checking weather 31 of Set 4 | chokurdakh
# tuggurt not found. Next...
# Checking weather 32 of Set 4 | dingle
# Checking weather 33 of Set 4 | wangqing
# Checking weather 34 of Set 4 | borisoglebskiy
# fartanesti not found. Next...
# Checking weather 35 of Set 4 | clyde river
# Checking weather 36 of Set 4 | richards bay
# Checking weather 37 of Set 4 | progreso
# Checking weather 38 of Set 4 | abu samrah
# Checking weather 39 of Set 4 | port shepstone
# Checking weather 40 of Set 4 | gwadar
# show low not found. Next...
# Checking weather 41 of Set 4 | bowen
# Checking weather 42 of Set 4 | hervey bay
# Checking weather 43 of Set 4 | adelaide
# Checking weather 44 of Set 4 | isangel
# Checking weather 45 of Set 4 | nanortalik
# Checking weather 46 of Set 4 | menongue
# Checking weather 47 of Set 4 | maceio
# Checking weather 48 of Set 4 | ajdabiya
# Checking weather 49 of Set 4 | geraldton
# Checking weather 1 of Set 5 | barra
# Checking weather 2 of Set 5 | connersville
# Checking weather 3 of Set 5 | aklavik
# Checking weather 4 of Set 5 | port hedland
# Checking weather 5 of Set 5 | vestmannaeyjar
# Checking weather 6 of Set 5 | fairbanks
# Checking weather 7 of Set 5 | sijunjung
# Checking weather 8 of Set 5 | esperance
# kesennuma not found. Next...
# Checking weather 9 of Set 5 | georgetown
# Checking weather 10 of Set 5 | calabozo
# Checking weather 11 of Set 5 | misratah
# urdzhar not found. Next...
# Checking weather 12 of Set 5 | york
# Checking weather 13 of Set 5 | nizhneudinsk
# Checking weather 14 of Set 5 | portland
# Checking weather 15 of Set 5 | seabra
# Checking weather 16 of Set 5 | vila franca do campo
# Checking weather 17 of Set 5 | miandrivazo
# la ferte-bernard not found. Next...
# Checking weather 18 of Set 5 | bathsheba
# saleaula not found. Next...
# Checking weather 19 of Set 5 | chai nat
# himora not found. Next...
# Checking weather 20 of Set 5 | saldanha
# Checking weather 21 of Set 5 | tucuman
# Checking weather 22 of Set 5 | shimoda
# Checking weather 23 of Set 5 | minab
# Checking weather 24 of Set 5 | eyl
# Checking weather 25 of Set 5 | veraval
# Checking weather 26 of Set 5 | pafos
# mizan teferi not found. Next...
# marcona not found. Next...
# Checking weather 27 of Set 5 | yermakovskoye
# Checking weather 28 of Set 5 | nanning
# Checking weather 29 of Set 5 | wuan
# Checking weather 30 of Set 5 | acapulco
# palabuhanratu not found. Next...
# Checking weather 31 of Set 5 | sao filipe
# Checking weather 32 of Set 5 | sinegorsk
# Checking weather 33 of Set 5 | bentiu
# Checking weather 34 of Set 5 | bambanglipuro
# Checking weather 35 of Set 5 | hasaki
# Checking weather 36 of Set 5 | tiznit
# Checking weather 37 of Set 5 | whitehorse
# Checking weather 38 of Set 5 | gandajika
# Checking weather 39 of Set 5 | sambava
# Checking weather 40 of Set 5 | biak
# Checking weather 41 of Set 5 | princeton
# Checking weather 42 of Set 5 | lakota
# Checking weather 43 of Set 5 | bambous virieux
# Checking weather 44 of Set 5 | coahuayana
# Checking weather 45 of Set 5 | havoysund
# Checking weather 46 of Set 5 | ulladulla
# Checking weather 47 of Set 5 | salalah
# Checking weather 48 of Set 5 | sri aman
# Checking weather 49 of Set 5 | uglovskoye
# Checking weather 1 of Set 6 | evensk
# Checking weather 2 of Set 6 | cuamba
# Checking weather 3 of Set 6 | talnakh
# Checking weather 4 of Set 6 | half moon bay
# Checking weather 5 of Set 6 | manali
# Checking weather 6 of Set 6 | northam
# Checking weather 7 of Set 6 | loudi
# Checking weather 8 of Set 6 | socorro
# Checking weather 9 of Set 6 | alamosa
# Checking weather 10 of Set 6 | kant
# Checking weather 11 of Set 6 | kasongo-lunda
# Checking weather 12 of Set 6 | luderitz
# Checking weather 13 of Set 6 | kuusamo
# Checking weather 14 of Set 6 | saskylakh
# Checking weather 15 of Set 6 | tommot
# Checking weather 16 of Set 6 | sipovo
# umm jarr not found. Next...
# Checking weather 17 of Set 6 | pisco
# Checking weather 18 of Set 6 | deputatskiy
# Checking weather 19 of Set 6 | kavaratti
# Checking weather 20 of Set 6 | kloulklubed
# te anau not found. Next...
# Checking weather 21 of Set 6 | nadapuram
# Checking weather 22 of Set 6 | zhigansk
# Checking weather 23 of Set 6 | labuhan
# Checking weather 24 of Set 6 | ormara
# Checking weather 25 of Set 6 | alyangula
# Checking weather 26 of Set 6 | linxia
# Checking weather 27 of Set 6 | boda
# Checking weather 28 of Set 6 | giresun
# Checking weather 29 of Set 6 | impfondo
# Checking weather 30 of Set 6 | tual
# Checking weather 31 of Set 6 | kedrovyy
# Checking weather 32 of Set 6 | hailar
# Checking weather 33 of Set 6 | anadyr
# Checking weather 34 of Set 6 | ilo
# Checking weather 35 of Set 6 | byron bay
# Checking weather 36 of Set 6 | tatawin
# Checking weather 37 of Set 6 | vostok
# Checking weather 38 of Set 6 | buala
# Checking weather 39 of Set 6 | kismayo
# Checking weather 40 of Set 6 | rzhev
# Checking weather 41 of Set 6 | lata
# Checking weather 42 of Set 6 | palauig
# Checking weather 43 of Set 6 | homer
# Checking weather 44 of Set 6 | port moresby
# Checking weather 45 of Set 6 | rocky mount
# umzimvubu not found. Next...
# Checking weather 46 of Set 6 | bamako
# Checking weather 47 of Set 6 | hayden
# Checking weather 48 of Set 6 | churapcha
# sentyabrskiy not found. Next...
# alfredo baquerizo moreno not found. Next...
# Checking weather 49 of Set 6 | visby
# Checking weather 1 of Set 7 | maua
# Checking weather 2 of Set 7 | taoudenni
# Checking weather 3 of Set 7 | atar
# saint leonard not found. Next...
# Checking weather 4 of Set 7 | marsh harbour
# Checking weather 5 of Set 7 | batagay-alyta
# Checking weather 6 of Set 7 | san policarpo
# Checking weather 7 of Set 7 | yulara
# Checking weather 8 of Set 7 | matara
# Checking weather 9 of Set 7 | fallon
# Checking weather 10 of Set 7 | sitka
# Checking weather 11 of Set 7 | roald
# Checking weather 12 of Set 7 | erdaojiang
# Checking weather 13 of Set 7 | namatanai
# Checking weather 14 of Set 7 | ballina
# Checking weather 15 of Set 7 | hovd
# Checking weather 16 of Set 7 | namie
# Checking weather 17 of Set 7 | ronne
# Checking weather 18 of Set 7 | ibra
# Checking weather 19 of Set 7 | ixtapa
# Checking weather 20 of Set 7 | plettenberg bay
# Checking weather 21 of Set 7 | innisfail
# Checking weather 22 of Set 7 | longyearbyen
# Checking weather 23 of Set 7 | semnan
# Checking weather 24 of Set 7 | nouadhibou
# Checking weather 25 of Set 7 | poum
# Checking weather 26 of Set 7 | yangliuqing
# Checking weather 27 of Set 7 | estacion coahuila
# Checking weather 28 of Set 7 | vila velha
# Checking weather 29 of Set 7 | port hardy
# Checking weather 30 of Set 7 | yerbogachen
# Checking weather 31 of Set 7 | faya
# Checking weather 32 of Set 7 | zyryanka
# Checking weather 33 of Set 7 | paso de los toros
# Checking weather 34 of Set 7 | angol
# Checking weather 35 of Set 7 | mersing
# Checking weather 36 of Set 7 | beloha
# Checking weather 37 of Set 7 | constitucion
# Checking weather 38 of Set 7 | ocos
# Checking weather 39 of Set 7 | laramie
# Checking weather 40 of Set 7 | douglas
# Checking weather 41 of Set 7 | mandera
# Checking weather 42 of Set 7 | aykhal
# Checking weather 43 of Set 7 | lavrentiya
# Checking weather 44 of Set 7 | gigmoto
# Checking weather 45 of Set 7 | zhezkazgan
# Checking weather 46 of Set 7 | erenhot
# Checking weather 47 of Set 7 | sur
# Checking weather 48 of Set 7 | pontianak
# Checking weather 49 of Set 7 | fare
# angra not found. Next...
# Checking weather 1 of Set 8 | high level
# allanmyo not found. Next...
# Checking weather 2 of Set 8 | kahului
# Checking weather 3 of Set 8 | sorland
# Checking weather 4 of Set 8 | vestmanna
# Checking weather 5 of Set 8 | whitianga
# borujan not found. Next...
# Checking weather 6 of Set 8 | manokwari
# tsihombe not found. Next...
# Checking weather 7 of Set 8 | miranda
# Checking weather 8 of Set 8 | beyneu
# Checking weather 9 of Set 8 | cabo san lucas
# Checking weather 10 of Set 8 | mareeba
# Checking weather 11 of Set 8 | fort morgan
# los llanos de aridane not found. Next...
# Checking weather 12 of Set 8 | kathu
# Checking weather 13 of Set 8 | tuatapere
# Checking weather 14 of Set 8 | yarmouth
# Checking weather 15 of Set 8 | roma
# haibowan not found. Next...
# Checking weather 16 of Set 8 | yongan
# Checking weather 17 of Set 8 | vardo
# Checking weather 18 of Set 8 | colesberg
# Checking weather 19 of Set 8 | eyrarbakki
# Checking weather 20 of Set 8 | troitskoye
# Checking weather 21 of Set 8 | chake chake
# Checking weather 22 of Set 8 | avera
# tumannyy not found. Next...
# Checking weather 23 of Set 8 | mercedes
# Checking weather 24 of Set 8 | gat
# Checking weather 25 of Set 8 | guerrero negro
# attawapiskat not found. Next...
# Checking weather 26 of Set 8 | manica
# Checking weather 27 of Set 8 | manaus
# Checking weather 28 of Set 8 | lock haven
# Checking weather 29 of Set 8 | sao felix do xingu
# Checking weather 30 of Set 8 | fasa
# Checking weather 31 of Set 8 | barra do garcas
# Checking weather 32 of Set 8 | rochelle
# Checking weather 33 of Set 8 | pacific grove
# Checking weather 34 of Set 8 | salym
# Checking weather 35 of Set 8 | hornepayne
# Checking weather 36 of Set 8 | hofn
# toliary not found. Next...
# Checking weather 37 of Set 8 | pasni
# Checking weather 38 of Set 8 | kasempa
# Checking weather 39 of Set 8 | ampanihy
# Checking weather 40 of Set 8 | khakhea
# Checking weather 41 of Set 8 | ikare
# Checking weather 42 of Set 8 | nianzishan
# Checking weather 43 of Set 8 | naze
# Checking weather 44 of Set 8 | san quintin
# Checking weather 45 of Set 8 | rincon
# Checking weather 46 of Set 8 | suruc
# Checking weather 47 of Set 8 | berlevag
# Checking weather 48 of Set 8 | belgrade
# Checking weather 49 of Set 8 | bud
# Checking weather 1 of Set 9 | bubaque
# Checking weather 2 of Set 9 | kuching
# Checking weather 3 of Set 9 | nizhniy ingash
# Checking weather 4 of Set 9 | mnogovershinnyy
# Checking weather 5 of Set 9 | mitsamiouli
# el paujil not found. Next...
# Checking weather 6 of Set 9 | huarmey
# Checking weather 7 of Set 9 | lasa
# inderborskiy not found. Next...
# Checking weather 8 of Set 9 | milos
# Checking weather 9 of Set 9 | ahipara
# Checking weather 10 of Set 9 | tessalit
# Checking weather 11 of Set 9 | tateyama
# Checking weather 12 of Set 9 | mwense
# Checking weather 13 of Set 9 | kokkola
# Checking weather 14 of Set 9 | seymchan
# Checking weather 15 of Set 9 | mulchen
# Checking weather 16 of Set 9 | caconda
# Checking weather 17 of Set 9 | clinton
# Checking weather 18 of Set 9 | shingu
# Checking weather 19 of Set 9 | severo-yeniseyskiy
# coolum beach not found. Next...
# Checking weather 20 of Set 9 | halifax
# Checking weather 21 of Set 9 | brae
# rungata not found. Next...
# Checking weather 22 of Set 9 | pangai
# Checking weather 23 of Set 9 | bezhta
# Checking weather 24 of Set 9 | atasu
# ruatoria not found. Next...
# Checking weather 25 of Set 9 | port macquarie
# Checking weather 26 of Set 9 | kamenica
# Checking weather 27 of Set 9 | antofagasta
# Checking weather 28 of Set 9 | urusha
# Checking weather 29 of Set 9 | souillac
# Checking weather 30 of Set 9 | bograd
# Checking weather 31 of Set 9 | kirakira
# Checking weather 32 of Set 9 | morgan city
# Checking weather 33 of Set 9 | tarko-sale
# broken hill not found. Next...
# Checking weather 34 of Set 9 | nioki
# Checking weather 35 of Set 9 | mantua
# Checking weather 36 of Set 9 | sao desiderio
# rawannawi not found. Next...
# Checking weather 37 of Set 9 | emerald
# Checking weather 38 of Set 9 | rura
# Checking weather 39 of Set 9 | exu
# Checking weather 40 of Set 9 | tautira
# Checking weather 41 of Set 9 | newport
# Checking weather 42 of Set 9 | tagusao
# Checking weather 43 of Set 9 | quirinopolis
# Checking weather 44 of Set 9 | katsuura
# la macarena not found. Next...
# Checking weather 45 of Set 9 | aswan
# Checking weather 46 of Set 9 | lazaro cardenas
# Checking weather 47 of Set 9 | livingston
# Checking weather 48 of Set 9 | grand-santi
# Checking weather 49 of Set 9 | hamilton
# am timan not found. Next...
# Checking weather 1 of Set 10 | diamantino
# Checking weather 2 of Set 10 | saint-denis
# Checking weather 3 of Set 10 | opportunity
# Checking weather 4 of Set 10 | southbridge
# Checking weather 5 of Set 10 | ketchikan
# Checking weather 6 of Set 10 | jinchang
# Checking weather 7 of Set 10 | anqing
# Checking weather 8 of Set 10 | akyab
# Checking weather 9 of Set 10 | galveston
# Checking weather 10 of Set 10 | saint-francois
# Checking weather 11 of Set 10 | iberia
# Checking weather 12 of Set 10 | seydi
# Checking weather 13 of Set 10 | rebrikha
# Checking weather 14 of Set 10 | omsukchan
# Checking weather 15 of Set 10 | dangriga
# Checking weather 16 of Set 10 | dunedin
# Checking weather 17 of Set 10 | pangnirtung
# Checking weather 18 of Set 10 | mancora
# Checking weather 19 of Set 10 | hope
# Checking weather 20 of Set 10 | westport
# Checking weather 21 of Set 10 | ust-maya
# Checking weather 22 of Set 10 | manhattan
# Checking weather 23 of Set 10 | padampur
# Checking weather 24 of Set 10 | ambon
# Checking weather 25 of Set 10 | omboue
# skagastrond not found. Next...
# Checking weather 26 of Set 10 | north bend
# Checking weather 27 of Set 10 | lahij
# Checking weather 28 of Set 10 | ekhabi
# Checking weather 29 of Set 10 | oro valley
# Checking weather 30 of Set 10 | bristol
# Checking weather 31 of Set 10 | melfort
# Checking weather 32 of Set 10 | baykalsk
# Checking weather 33 of Set 10 | farsund
# Checking weather 34 of Set 10 | bonavista
# Checking weather 35 of Set 10 | itoman
# Checking weather 36 of Set 10 | illela
# Checking weather 37 of Set 10 | muzhi
# Checking weather 38 of Set 10 | ostersund
# el arenal not found. Next...
# Checking weather 39 of Set 10 | clifton springs
# Checking weather 40 of Set 10 | flinders
# Checking weather 41 of Set 10 | gonda
# Checking weather 42 of Set 10 | bucerias
# vaitupu not found. Next...
# Checking weather 43 of Set 10 | brufut
# Checking weather 44 of Set 10 | coquimbo
# Checking weather 45 of Set 10 | tulsipur
# Checking weather 46 of Set 10 | yining
# Checking weather 47 of Set 10 | suntar
# Checking weather 48 of Set 10 | ngunguru
# Checking weather 49 of Set 10 | dali
# Checking weather 1 of Set 11 | kandhla
# Checking weather 2 of Set 11 | mitu
# Checking weather 3 of Set 11 | porto santo
# Checking weather 4 of Set 11 | bousso
# Checking weather 5 of Set 11 | xuddur
# Checking weather 6 of Set 11 | khrystynivka
# Checking weather 7 of Set 11 | baruun-urt
# Checking weather 8 of Set 11 | kungurtug
# Checking weather 9 of Set 11 | rocha
# Checking weather 10 of Set 11 | hopewell
# Checking weather 11 of Set 11 | olenegorsk
# Checking weather 12 of Set 11 | lianran
# Checking weather 13 of Set 11 | szajol
# Checking weather 14 of Set 11 | camacha
# Checking weather 15 of Set 11 | willmar
# Checking weather 16 of Set 11 | meulaboh
# Checking weather 17 of Set 11 | turukhansk
# Checking weather 18 of Set 11 | gaillac
# Checking weather 19 of Set 11 | japura
# Checking weather 20 of Set 11 | kandrian
# Checking weather 21 of Set 11 | kormista
# Checking weather 22 of Set 11 | sao gabriel da cachoeira
# Checking weather 23 of Set 11 | wajima
# Checking weather 24 of Set 11 | celestun
# Checking weather 25 of Set 11 | cherskiy
# Checking weather 26 of Set 11 | korla
# hihifo not found. Next...
# Checking weather 27 of Set 11 | kamaishi
# Checking weather 28 of Set 11 | necochea
# Checking weather 29 of Set 11 | dicabisagan
# Checking weather 30 of Set 11 | puerto carreno
# Checking weather 31 of Set 11 | ferkessedougou
# Checking weather 32 of Set 11 | baracoa
# Checking weather 33 of Set 11 | kargasok
# Checking weather 34 of Set 11 | oxapampa
# Checking weather 35 of Set 11 | amahai
# Checking weather 36 of Set 11 | telimele
# Checking weather 37 of Set 11 | krasnoselkup
# Checking weather 38 of Set 11 | bahia honda
# Checking weather 39 of Set 11 | egvekinot
# Checking weather 40 of Set 11 | buchanan
# Checking weather 41 of Set 11 | baykit
# ------------------------------
# All Done!
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary for dataframe to reference
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}
# create dataframe
weather_df = pd.DataFrame(weather_dict)

# check
weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0       tiksi         100      RU  1643609624        99  71.6872  128.8694
# 1       vaini         100      TO  1643609625        70 -21.2000 -175.2000
# 2      marzuq          54      YE  1643609625        40  14.4000   46.4667
# 3    lorengau         100      PG  1643609626        81  -2.0226  147.2712
# 4  bredasdorp         100      ZA  1643609626        83 -34.5322   20.0403
#
#    Max Temp  Wind Speed
# 0    -25.33        1.58
# 1     27.38        6.91
# 2     21.22        1.14
# 3     27.38        7.12
# 4     23.49        4.12

# %%
#output to csv
#weather_df.to_csv(output_data_file)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df['Humidity'].sort_values(ascending = False)
#This indicates that some cities in our list have a humidity of 100% but not over it. 
#A little research indicates that humidity levels over 100% are only really possible at very high altitudes, making it pretty unlikely for there to be cities built.
# Out:
# 37     100
# 477    100
# 35     100
# 451    100
# 325    100
#       ...
# 121     14
# 299     14
# 68      14
# 126     14
# 296     13
# Name: Humidity, Length: 531, dtype: int64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Max Temp'],color  = 'blue', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.title("Latitude vs Max Temp")
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max Temp (Celcius)')
plt.ylim (min(weather_df['Max Temp'])-10, max(weather_df['Max Temp']) + 10)
plt.savefig('fig1.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Humidity'],color  = 'tomato', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.title("Latitude vs Humidity (%)")
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim (min(weather_df['Humidity'])-10, max(weather_df['Humidity']) + 10)
plt.savefig('fig2.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Cloudiness'],color  = 'cornflowerblue', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.title("Latitude vs Cloudiness")
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.ylim (min(weather_df['Cloudiness'])-10, max(weather_df['Cloudiness']) + 10)
plt.savefig('fig3.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Wind Speed'],color  = 'goldenrod', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.title("Latitude vs Wind Speed")
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.ylim (min(weather_df['Wind Speed'])-2, max(weather_df['Wind Speed']) + 10)
plt.savefig('fig4.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Linear Regression

# %%
#split the data into northern and southern hemispheres
north_df = weather_df.loc[pd.to_numeric(weather_df["Lat"]).astype(float) > 0, :]
south_df = weather_df.loc[pd.to_numeric(weather_df["Lat"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set variables
x_val = north_df['Lat']
y_val = north_df['Max Temp']
#linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line}")
#plot
plt.scatter(x_val,y_val, color  = 'cornflowerblue', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.plot(x_val,regress_values,"r-")
plt.annotate(line,(6,-20),fontsize=12,color="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')

print(f"The r-squared is: {rvalue}")
print("There is a negative correlation.")
print("The closer you are to be equator in the Northern Hemisphere, the warmer it is.")
plt.show()
# Out:
# Regression line equation is: y = -0.74x + 32.14
# The r-squared is: -0.8886308273768487
# There is a negative correlation.
# The closer you are to be equator in the Northern Hemisphere, the warmer it is.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set variables
x_val = south_df['Lat']
y_val = south_df['Max Temp']
#linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line}")
#plot
plt.scatter(x_val,y_val, color  = 'cornflowerblue', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.plot(x_val,regress_values,"r-")
plt.annotate(line,(-50,10),fontsize=12,color="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')

print(f"The r-squared is: {rvalue}")
print("There is a positive correlation.")
print("The closer you are to the equator in the Souther Hemisphere, the warmer it is.")
plt.show()
# Out:
# Regression line equation is: y = 0.18x + 27.21
# The r-squared is: 0.41313113509762883
# There is a positive correlation.
# The closer you are to the equator in the Souther Hemisphere, the warmer it is.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set variables
x_val = north_df['Lat']
y_val = north_df['Humidity']
#linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line}")
#plot
plt.scatter(x_val,y_val, color  = 'cornflowerblue', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.plot(x_val,regress_values,"r-")
plt.annotate(line,(50,20),fontsize=12,color="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')

print(f"The r-squared is: {rvalue}")
print("There is a positive correlation.")
print("Moving away from the equator in the northern hemisphere sees an increase in humidity.")
plt.show()
# Out:
# Regression line equation is: y = 0.53x + 49.24
# The r-squared is: 0.4518934715434008
# There is a positive correlation.
# Moving away from the equator in the northern hemisphere sees an increase in humidity.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_val = south_df['Lat']
y_val = south_df['Humidity']
#linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line}")
#plot
plt.scatter(x_val,y_val, color  = 'cornflowerblue', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.plot(x_val,regress_values,"r-")
plt.annotate(line,(-18,40),fontsize=12,color="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')

print(f"The r-squared is: {rvalue}")
print("There is a weak positive correlation.")
print("Moving toward the equator in the sounthern hemisphere does increase humidity, but not by very much")
plt.show()
# Out:
# Regression line equation is: y = 0.22x + 79.49
# The r-squared is: 0.20010889709754098
# There is a weak positive correlation.
# Moving toward the equator in the sounthern hemisphere does increase humidity, but not by very much

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_val = north_df['Lat']
y_val = north_df['Cloudiness']
#linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line}")
#plot
plt.scatter(x_val,y_val, color  = 'cornflowerblue', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.plot(x_val,regress_values,"r-")
plt.annotate(line,(70,20),fontsize=12,color="black")
plt.xlabel('Latitude')
plt.ylabel('Cloundiness')
plt.title('Northern Hemisphere - Cloundiness (%) vs. Latitude Linear Regression')

print(f"The r-squared is: {rvalue}")
print("There is a weak positive correlation.")
print("Moving away from the equator in the northern hemisphere does increase cloudiness.")
plt.show()
# Out:
# Regression line equation is: y = 0.6x + 31.47
# The r-squared is: 0.28885337899144947
# There is a weak positive correlation.
# Moving away from the equator in the northern hemisphere does increase cloudiness, but not by very much

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_val = south_df['Lat']
y_val = south_df['Cloudiness']
#linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line}")
#plot
plt.scatter(x_val,y_val, color  = 'cornflowerblue', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.plot(x_val,regress_values,"r-")
plt.annotate(line,(0,0),fontsize=12,color="black")
plt.xlabel('Latitude')
plt.ylabel('Cloundiness')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')

print(f"The r-squared is: {rvalue}")
print("There is a weak positive correlation.")
print("Moving toward the equator in the northern hemisphere does increase cloudiness")
plt.show()
# Out:
# Regression line equation is: y = 0.98x + 83.29
# The r-squared is: 0.33668196814624746
# There is a weak positive correlation.
# Moving toward the equator in the northern hemisphere does increase cloudiness

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_val = north_df['Lat']
y_val = north_df['Wind Speed']
#linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line}")
#plot
plt.scatter(x_val,y_val, color  = 'cornflowerblue', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.plot(x_val,regress_values,"r-")
plt.annotate(line,(0,15),fontsize=12,color="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')

print(f"The r-squared is: {rvalue}")
print("There is a weak positive correlation.")
print("Moving away from the equator in the northern hemisphere does increase windiness, but not by very much")
plt.show()
# Out:
# Regression line equation is: y = 0.02x + 2.82
# The r-squared is: 0.1057312494348859
# There is a weak positive correlation.
# Moving away from the equator in the northern hemisphere does increase windiness, but not by very much

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_val = south_df['Lat']
y_val = south_df['Wind Speed']
#linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line}")
#plot
plt.scatter(x_val,y_val, color  = 'cornflowerblue', alpha = .5, linewidth = 1, edgecolor = 'black')
plt.plot(x_val,regress_values,"r-")
plt.annotate(line,(-55,0),fontsize=12,color="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')

print(f"The r-squared is: {rvalue}")
print("There is a weak negative correlation.")
print("Moving toward the equator in the southern hemisphere does decrease wind speed, but not by very much")
plt.show()
# Out:
# Regression line equation is: y = -0.03x + 2.99
# The r-squared is: -0.15010172766426208
# There is a weak negative correlation.
# Moving toward the equator in the southern hemisphere does decrease wind speed, but not by very much
